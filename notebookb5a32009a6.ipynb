# %%
import numpy as np
import pandas as pd

# %%
tracks = pd.read_csv('/kaggle/input/-spotify-tracks-dataset/dataset.csv')
tracks.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
tracks = tracks.drop('Unnamed: 0', axis=1)
tracks.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
print(tracks.isnull().sum())
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
tracks.dropna(inplace = True)

# %%
tracks.dtypes
# Out:
# track_id             object
# artists              object
# album_name           object
# track_name           object
# popularity            int64
# duration_ms           int64
# explicit               bool
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# track_genre          object
# dtype: object

# %%
tracks = tracks.drop(columns=["duration_ms"])
tracks.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  explicit  danceability  energy  \
# 0                      Comedy          73     False         0.676  0.4610
# 1            Ghost - Acoustic          55     False         0.420  0.1660
# 2              To Begin Again          57     False         0.438  0.3590
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

num_cols = [ 
    "popularity", "danceability", "energy", "key", "loudness", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo", "time_signature"
]

scaler = MinMaxScaler()
tracks[num_cols] = scaler.fit_transform(tracks[num_cols])
tracks.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  explicit  danceability  energy  \
# 0                      Comedy        0.73     False      0.686294  0.4610
# 1            Ghost - Acoustic        0.55     False      0.426396  0.1660
# 2              To Begin Again        0.57     False      0.444670  0.3590
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# Encoding categorical features
tracks["artists"] = encoder.fit_transform(tracks["artists"])
tracks["album_name"] = encoder.fit_transform(tracks["album_name"])
tracks["track_genre"] = encoder.fit_transform(tracks["track_genre"])

# Fixing explicit column (True/False → 1/0)
tracks["explicit"] = tracks["explicit"].astype(int)
tracks.head()
# Out:
#                  track_id  artists  album_name                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV    10357        8100                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A     3287       14796            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b    12397       39162              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx    14839        8580  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K     5255       16899                     Hold On
#
#    popularity  explicit  danceability  energy       key  loudness  mode  \
# 0        0.73         0      0.686294  0.4610  0.090909  0.791392     0
# 1        0.55         0      0.426396  0.1660  0.090909  0.597377     1
# 2        0.57         0      0.444670  0.3590  0.000000  0.736123     1
# 3        0.71         0      0.270051  0.0596  0.000000  0.573701     1
# 4        0.82         0      0.627411  0.4430  0.181818  0.737103     1
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# ...

# %%
from sklearn.neighbors import NearestNeighbors

# Drop non-numeric columns
features = tracks.drop(columns=["track_id", "track_name"])

# Fit KNN Model
nn_model = NearestNeighbors(n_neighbors=10, metric="cosine", algorithm="auto")
nn_model.fit(features)

def get_similar_songs(track_index, n=10, artist_bias=0.1):
    # Ensure track_index is within range
    if track_index >= len(features) or track_index < 0:
        raise ValueError("Track index is out of bounds.")

    # Extract features of the given track and keep column names
    track_features = pd.DataFrame([features.iloc[track_index]], columns=features.columns)

    # Find nearest neighbors
    distances, indices = nn_model.kneighbors(track_features, n_neighbors=n+1)

    # Retrieve similar songs (excluding the input track itself)
    similar_songs = tracks.iloc[indices[0][1:]].copy()
    
    # Use encoded "artist" column instead of "artists"
    original_artist = tracks.iloc[track_index]["artists"]

    # Adjust distances for same artist (vectorized)
    artist_mask = (similar_songs["artists"] == original_artist).astype(float)
    similar_songs["adjusted_distance"] = distances[0][1:] - (artist_bias * artist_mask)

    # Sort by adjusted distance
    similar_songs = similar_songs.sort_values(by="adjusted_distance").head(n)

    return similar_songs[["track_id", "track_name"]]


# Example usage
similar_songs = get_similar_songs(81004, n=10, artist_bias=0.9)
print(similar_songs)
# Out:
#                      track_id                            track_name
# 65931  2BPXILn0MqOe5WroVXlvN1  I Will Go To You Like the First Snow
# 73037  61dgKii1YUE2sS7SZk00Ky                                Bounce
# 98162  03m03OVQGPuzt8Rw2r0a7t          Do You Hear The People Sing?
# 50253  5YjJNXhbMLBfxErj4DDgv3                       Guerra de razas
# 50653  6gWo8TCcq6dqQxpbI69L4r                   Lo mejor de lo peor
# 50805  5JRJHXs4nFiAeLZHJNSau6                                Amigos
# 50404  7fpEq4VraGYZZWXfWLk3sP                      Pueblos erguidos
# 50905  4mswXUnMJrQ1mPAQ9EtQ2e                      Sabia naturaleza
# 50806  21Vt3CoNMntSmRQTLRV0SC                                  Alas
# 50503  6r6OQDr6qfg9JNWN277bM2                        Antes de morir

# %%
SongNumber = tracks[tracks["track_name"].str.contains("Starboy", case=False, na=False)]
print(SongNumber[["track_id", "track_name", "artists"]])
# Out:
#                       track_id track_name  artists
# 81004   7MXVkk9YMctZqd1Srtv4MB    Starboy    27724
# 81113   2MugnVou4z1c7oh1kWHfZO    Starboy    27724
# 81119   0Jfqd9wbqlDAT5wCrck0Dc    Starboy    27724
# 109361  26Yk79sAcZyBZZGTvo1Woi    Starboy    10876
